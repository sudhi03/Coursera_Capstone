# %%
#import Libraries
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json
from geopy.geocoders import Nominatim
import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import geocoder
import time
import folium


print('Import Success')
# Out:
# Import Success

# %%
wikipedia_link = 'https://en.wikipedia.org/wiki/List_of_areas_of_London'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:64.0) Gecko/20100101 Firefox/64.0'}
wikipedia_page = requests.get(wikipedia_link, headers = headers)
wikipedia_page
# Out:
# <Response [200]>

# %%
# Cleans html file
soup = BeautifulSoup(wikipedia_page.content, 'html.parser')
# This extracts the "tbody" within the table where class is "wikitable sortable"
table = soup.find('table', {'class':'wikitable sortable'}).tbody

# %%
# Extracts all "tr" (table rows) within the table above
rows = table.find_all('tr')

# %%
# Extracts the column headers, removes and replaces possible '\n' with space for the "th" tag
columns = [i.text.replace('\n', '')
           for i in rows[0].find_all('th')]

# %%
# Converts columns to pd dataframe
df = pd.DataFrame(columns = columns)
df
# Out:
# Empty DataFrame
# Columns: [Location, London borough, Post town, Postcode district, Dial code, OS grid ref]
# Index: []

# %%
# Extracts every row with corresponding columns
# Then appends the values to the create pd dataframe "df"
# Please note that the first row (row[0]) is skipped because it is already the header
for i in range(1, len(rows)):
    tds = rows[i].find_all('td')
    
    
    if len(tds) == 7:
        values = [tds[0].text, tds[1].text, tds[2].text.replace('\n', ''.replace('\xa0','')), tds[3].text, tds[4].text.replace('\n', ''.replace('\xa0','')), tds[5].text.replace('\n', ''.replace('\xa0','')), tds[6].text.replace('\n', ''.replace('\xa0',''))]
    else:
        values = [td.text.replace('\n', '').replace('\xa0','') for td in tds]
        
        df = df.append(pd.Series(values, index = columns), ignore_index = True)

        df

# %%
df.head()
# Out:
#       Location                     London borough       Post town  \
# 0   Abbey Wood             Bexley,  Greenwich [2]          LONDON
# 1        Acton  Ealing, Hammersmith and Fulham[3]          LONDON
# 2    Addington                         Croydon[3]         CROYDON
# 3   Addiscombe                         Croydon[3]         CROYDON
# 4  Albany Park                             Bexley  BEXLEY, SIDCUP
#
#   Postcode district Dial code OS grid ref
# 0               SE2       020    TQ465785
# 1            W3, W4       020    TQ205805
# 2               CR0       020    TQ375645
# 3               CR0       020    TQ345665
# 4         DA5, DA14       020    TQ478728

# %%
df = df.rename(index=str, columns = {'Location': 'Location', 'London\xa0borough': 'Borough', 'Post town': 'Post-town', 'Postcode\xa0district': 'Postcode', 'Dial\xa0code': 'Dial-code', 'OS grid ref': 'OSGridRef'})

# %%
df.head()
# Out:
#       Location                            Borough       Post-town   Postcode  \
# 0   Abbey Wood             Bexley,  Greenwich [2]          LONDON        SE2
# 1        Acton  Ealing, Hammersmith and Fulham[3]          LONDON     W3, W4
# 2    Addington                         Croydon[3]         CROYDON        CR0
# 3   Addiscombe                         Croydon[3]         CROYDON        CR0
# 4  Albany Park                             Bexley  BEXLEY, SIDCUP  DA5, DA14
#
#   Dial-code OSGridRef
# 0       020  TQ465785
# 1       020  TQ205805
# 2       020  TQ375645
# 3       020  TQ345665
# 4       020  TQ478728

# %%
# Looking the data, under the Borough, there are borough names with []. These are references extracted from the wiki page. So remove these, the following was done:
df['Borough'] = df['Borough'].map(lambda x: x.rstrip(']').rstrip('0123456789').rstrip('['))

# %%
df.shape
# Out:
# (533, 6)

# %%
df.head()
# Out:
#       Location                         Borough       Post-town   Postcode  \
# 0   Abbey Wood             Bexley,  Greenwich           LONDON        SE2
# 1        Acton  Ealing, Hammersmith and Fulham          LONDON     W3, W4
# 2    Addington                         Croydon         CROYDON        CR0
# 3   Addiscombe                         Croydon         CROYDON        CR0
# 4  Albany Park                          Bexley  BEXLEY, SIDCUP  DA5, DA14
#
#   Dial-code OSGridRef
# 0       020  TQ465785
# 1       020  TQ205805
# 2       020  TQ375645
# 3       020  TQ345665
# 4       020  TQ478728

# %% [markdown]
# London is big and due to the limitations in the number of calls for the Foursquare API, the following assumptions are made to confine this project to only South East London.
#
# Assumption 1: Where the Postcode are more than one, (for example, in Acton, there are 2 postcodes - W3 and W4), the postcodes are spread to multi-rows and assigned the same values from the other columns.

# %%
df0 = df.drop('Postcode', axis=1).join(df['Postcode'].str.split(',', expand=True).stack().reset_index(level=1, drop=True).rename('Postcode'))

# %%
df0.head(5)
# Out:
#       Location                         Borough Post-town Dial-code OSGridRef  \
# 0   Abbey Wood             Bexley,  Greenwich     LONDON       020  TQ465785
# 1        Acton  Ealing, Hammersmith and Fulham    LONDON       020  TQ205805
# 1        Acton  Ealing, Hammersmith and Fulham    LONDON       020  TQ205805
# 10       Angel                       Islington    LONDON       020  TQ345665
# 10       Angel                       Islington    LONDON       020  TQ345665
#
#    Postcode
# 0       SE2
# 1        W3
# 1        W4
# 10      EC1
# 10       N1

# %%
df0.shape
# Out:
# (637, 6)

# %% [markdown]
# Assumption 2: From the data, only the 'Location', 'Borough', 'Postcode', 'Post-town' will be used for this project. So they are extracted into a new data frame.

# %%
df1 = df0[['Location', 'Borough', 'Postcode', 'Post-town']].reset_index(drop=True)

# %%
df1.head(5)
# Out:
#      Location                         Borough Postcode Post-town
# 0  Abbey Wood             Bexley,  Greenwich       SE2    LONDON
# 1       Acton  Ealing, Hammersmith and Fulham       W3    LONDON
# 2       Acton  Ealing, Hammersmith and Fulham       W4    LONDON
# 3       Angel                       Islington      EC1    LONDON
# 4       Angel                       Islington       N1    LONDON

# %% [markdown]
# Assumption 3: Now, only the Boroughs with London Post-town will be used for our search of location. Therefore, all the non-post-town are dropped.

# %%
df2 = df1
df21 = df2[df2['Post-town'].str.contains('LONDON')]

# %%
df21.head(5)
# Out:
#      Location                         Borough Postcode Post-town
# 0  Abbey Wood             Bexley,  Greenwich       SE2    LONDON
# 1       Acton  Ealing, Hammersmith and Fulham       W3    LONDON
# 2       Acton  Ealing, Hammersmith and Fulham       W4    LONDON
# 3       Angel                       Islington      EC1    LONDON
# 4       Angel                       Islington       N1    LONDON

# %%
df21.shape
# Out:
# (380, 4)

# %%
df3 = df21[['Location', 'Borough', 'Postcode']].reset_index(drop=True) # Re-assigns the df21 to new dataframe without the Post-town

# %%
df3.head(10)
# Out:
#       Location                         Borough Postcode
# 0   Abbey Wood             Bexley,  Greenwich       SE2
# 1        Acton  Ealing, Hammersmith and Fulham       W3
# 2        Acton  Ealing, Hammersmith and Fulham       W4
# 3        Angel                       Islington      EC1
# 4        Angel                       Islington       N1
# 5   Church End                           Brent     NW10
# 6   Church End                          Barnet       N3
# 7      Clapham             Lambeth, Wandsworth      SW4
# 8  Clerkenwell                       Islington      EC1
# 9    Colindale                          Barnet      NW9

# %%
df_london = df3
df_london.to_csv('LondonLocations.csv', index = False)

# %% [markdown]
# Assumption 4: Due to its more diverse outlook, proximity to afro-caribbean markets and accessible facilities, only the South East areas of London will be considered for our analysis. The South East areas has postcodes starting with SE.

# %%
df_london.head(5)
# Out:
#      Location                         Borough Postcode
# 0  Abbey Wood             Bexley,  Greenwich       SE2
# 1       Acton  Ealing, Hammersmith and Fulham       W3
# 2       Acton  Ealing, Hammersmith and Fulham       W4
# 3       Angel                       Islington      EC1
# 4       Angel                       Islington       N1

# %%
df_london.Postcode = df_london.Postcode.str.strip()

# %%
df_london.head(5)
# Out:
#      Location                         Borough Postcode
# 0  Abbey Wood             Bexley,  Greenwich       SE2
# 1       Acton  Ealing, Hammersmith and Fulham       W3
# 2       Acton  Ealing, Hammersmith and Fulham       W4
# 3       Angel                       Islington      EC1
# 4       Angel                       Islington       N1

# %%
df_se = df_london[df_london['Postcode'].str.startswith(('SE'))].reset_index(drop=True)

# %%
df_se.head(10)
# Out:
#          Location              Borough Postcode
# 0      Abbey Wood  Bexley,  Greenwich       SE2
# 1    Crofton Park             Lewisham      SE4
# 2       Crossness               Bexley      SE2
# 3  Crystal Palace              Bromley     SE19
# 4  Crystal Palace              Bromley     SE20
# 5  Crystal Palace              Bromley     SE26
# 6    Denmark Hill            Southwark      SE5
# 7        Deptford             Lewisham      SE8
# 8         Dulwich            Southwark     SE21
# 9    East Dulwich            Southwark     SE22

# %% [markdown]
# Assumption 5: This assumption will focus on the demography of London where there are predominantly more multicultural groups. According to the proportion of races by London borough as seen in Demography of London, the top 5 Black Africans or Caribbeans are shown below:

# %%
demograph_link = 'https://en.wikipedia.org/wiki/Demography_of_London'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:64.0) Gecko/20100101 Firefox/64.0'}
demograph_page = requests.get(demograph_link, headers = headers)
soup1 = BeautifulSoup(demograph_page.content, 'html.parser')
table1 = soup1.find('table', {'class':'wikitable sortable'}).tbody
rows1 = table1.find_all('tr')
columns1 = [i.text.replace('\n', '')
           for i in rows1[0].find_all('th')]

# %%
columns1
# Out:
# ['Local authority', 'White', 'Mixed', 'Asian', 'Black', 'Other']

# %%
demo_london = pd.DataFrame(columns = columns1)

# %%
demo_london.head(5)
# Out:
# Empty DataFrame
# Columns: [Local authority, White, Mixed, Asian, Black, Other]
# Index: []

# %%
for j in range(1, len(rows1)):
    tds1 = rows1[j].find_all('td')
    if len(tds1) == 7:
        values1 = [tds1[0].text, tds1[1].text, tds1[2].text.replace('\n', ''.replace('\xa0','')), tds1[3].text, tds1[4].text.replace('\n', ''.replace('\xa0','')), tds1[5].text.replace('\n', ''.replace('\xa0',''))]
    else:
        values1 = [td1.text.replace('\n', '').replace('\xa0','') for td1 in tds1]
        
        demo_london = demo_london.append(pd.Series(values1, index = columns1), ignore_index = True)

        demo_london

# %%
demo_london['Black'] = demo_london['Black'].astype('float')

# %%
demo_london_sorted = demo_london.sort_values(by='Black', ascending = False)

# %%
demo_london_sorted.head(5)
# Out:
#    Local authority White Mixed Asian  Black Other
# 22        Lewisham  53.5   7.4   9.3   27.2   2.6
# 27       Southwark  54.3   6.2   9.4   26.9   3.3
# 21         Lambeth  57.1   7.6   6.9   25.9   2.4
# 11         Hackney  54.7   6.4  10.5   23.1   5.3
# 7          Croydon  55.1   6.6  16.4   20.2   1.8

# %% [markdown]
# Assumption 6: Our next assumption will be based on the top 5 areas will significantly high "Black", "Mixed" and other races. These leaves us with Lewisham, Southwark, Lambeth, Hackney and Croydon.

# %%
df_se
# Out:
#                                           Location              Borough  \
# 0                                       Abbey Wood  Bexley,  Greenwich
# 1                                     Crofton Park             Lewisham
# 2                                        Crossness               Bexley
# 3                                   Crystal Palace              Bromley
# 4                                   Crystal Palace              Bromley
# 5                                   Crystal Palace              Bromley
# 6                                     Denmark Hill            Southwark
# 7                                         Deptford             Lewisham
# 8                                          Dulwich            Southwark
# 9                                     East Dulwich            Southwark
# 10                             Elephant and Castle            Southwark
# 11                             Elephant and Castle            Southwark
# 12                             Elephant and Castle            Southwark
# 13                                          Eltham            Greenwich
# 14                                      Falconwood    Bexley, Greenwich
# 15                                        Bankside            Southwark
# 16                                     Forest Hill             Lewisham
# 17                                      Gipsy Hill              Lambeth
# 18                                      Gipsy Hill              Lambeth
# 19                                       Greenwich            Greenwich
# 20                                      Grove Park             Lewisham
# 21                                      Herne Hill              Lambeth
# 22                                    Hither Green             Lewisham
# 23                                       Honor Oak             Lewisham
# 24                                       Horn Park  Greenwich, Lewisham
# 25                                      Kennington   Lambeth, Southwark
# 26                                       Kidbrooke            Greenwich
# 27                                        Ladywell             Lewisham
# 28                                        Ladywell             Lewisham
# 29                                         Lambeth              Lambeth
# 30                                             Lee             Lewisham
# 31                                        Lewisham             Lewisham
# 32                                       Beckenham              Bromley
# 33                                       Longlands               Bexley
# 34                                       Maze Hill            Greenwich
# 35                                     Middle Park            Greenwich
# 36                                      Mottingham              Bromley
# 37                                       New Cross             Lewisham
# 38                                      New Eltham            Greenwich
# 39                                       Newington            Southwark
# 40                                       Newington            Southwark
# 41                                         Nunhead            Southwark
# 42                                            Oval              Lambeth
# 43                                      Bellingham             Lewisham
# 44                                         Peckham            Southwark
# 45                                           Penge              Bromley
# 46                                       Plumstead            Greenwich
# 47                                     Rotherhithe            Southwark
# 48                                        Selhurst              Croydon
# 49                                  Shooter's Hill            Greenwich
# 50                                      Bermondsey            Southwark
# 51                                   South Norwood              Croydon
# 52                                        Southend             Lewisham
# 53                                        St Johns             Lewisham
# 54              Bexleyheath (also Bexley New Town)               Bexley
# 55                                    Surrey Quays            Southwark
# 56  Sydenham (also Lower Sydenham, Upper Sydenham)    Lewisham, Bromley
# 57                                   Sydenham Hill  Lewisham, Southwark
# 58                                   Sydenham Hill  Lewisham, Southwark
# 59                                      Thamesmead    Bexley, Greenwich
# 60                                      Thamesmead    Bexley, Greenwich
# 61                                      Tulse Hill              Lambeth
# 62                                      Tulse Hill              Lambeth
# 63                                   Upper Norwood              Croydon
# 64                                        Walworth            Southwark
# 65                                       Well Hall            Greenwich
# 66                                      Blackheath             Lewisham
# 67                                      West Heath               Bexley
# 68                       Blackheath Royal Standard            Greenwich
# 69                       Blackheath Royal Standard            Greenwich
# 70                                    West Norwood              Lambeth
# 71                                  Westcombe Park            Greenwich
# 72                                        Woolwich            Greenwich
# 73                                         Brixton              Lambeth
# 74                                        Brockley             Lewisham
# 75                                      Camberwell            Southwark
# 76                                         Catford             Lewisham
# 77                                        Charlton            Greenwich
# 78                                         Anerley              Bromley
# 79                                       Chinbrook             Lewisham
#
#    Postcode
# 0       SE2
# 1       SE4
# 2       SE2
# 3      SE19
# 4      SE20
# 5      SE26
# 6       SE5
# 7       SE8
# 8      SE21
# 9      SE22
# 10      SE1
# 11     SE11
# 12     SE17
# 13      SE9
# 14      SE9
# 15      SE1
# 16     SE23
# 17     SE19
# 18     SE27
# 19     SE10
# 20     SE12
# 21     SE24
# 22     SE13
# 23     SE23
# 24     SE12
# 25     SE11
# 26      SE3
# 27      SE4
# 28     SE13
# 29      SE1
# 30     SE12
# 31     SE13
# 32     SE20
# 33      SE9
# 34     SE10
# 35      SE9
# 36      SE9
# 37     SE14
# 38      SE9
# 39      SE1
# 40     SE17
# 41     SE15
# 42     SE11
# 43      SE6
# 44     SE15
# 45     SE20
# 46     SE18
# 47     SE16
# 48     SE25
# 49     SE18
# 50      SE1
# 51     SE25
# 52      SE6
# 53      SE4
# 54      SE2
# 55     SE16
# 56     SE26
# 57     SE21
# 58     SE26
# 59     SE28
# 60      SE2
# 61     SE24
# 62     SE27
# 63     SE19
# 64     SE17
# 65      SE9
# 66      SE3
# 67      SE2
# 68      SE3
# 69     SE12
# 70     SE27
# 71      SE3
# 72     SE18
# 73      SE5
# 74      SE4
# 75      SE5
# 76      SE6
# 77      SE7
# 78     SE20
# 79     SE12

# %%
df_se_top = df_se[df_se['Borough'].isin(['Lewisham', 'Southwark', 'Lambeth', 'Hackney', 'Croydon'])].reset_index(drop=True)

# %%
df_se_top.head(5)
# Out:
#        Location    Borough Postcode
# 0  Crofton Park   Lewisham      SE4
# 1  Denmark Hill  Southwark      SE5
# 2      Deptford   Lewisham      SE8
# 3       Dulwich  Southwark     SE21
# 4  East Dulwich  Southwark     SE22

# %%
df_se_top.shape
# Out:
# (46, 3)

# %%
df_se.shape
# Out:
# (80, 3)

# %% [markdown]
# So we have our working dataframe to be df_se_top to work with.

# %% [markdown]
# 2.1.2 Dataset 2:
#
# In obtaining the location data of the locations, the Geocoder package is used with the arcgis_geocoder to obtain the latitude and longitude of the needed locations.
#
# These will help to create a new dataframe that will be used subsequently for the South East London areas.

# %%
# Geocoder starts here
# Defining a function to use --> get_latlng()'''


def get_latlng(arcgis_geocoder):
    
    # Initialize the Location (lat. and long.) to "None"
    lat_lng_coords = None
    
    # While loop helps to create a continous run until all the location coordinates are geocoded
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, London, United Kingdom'.format(arcgis_geocoder))
        lat_lng_coords = g.latlng
    return lat_lng_coords
# Geocoder ends here

# %%
#Applying Geocoder to dataframe df_se_top 
start = time.time()

postal_codes = df_se_top['Postcode']    
coordinates = [get_latlng(postal_code) for postal_code in postal_codes.tolist()]

end = time.time()
print("Time of execution: ", end - start, "seconds")
# Out:
# Time of execution:  57.57765865325928 seconds

# %%
df_se_loc = df_se_top

# The obtained coordinates (latitude and longitude) are joined with the dataframe as shown
df_se_coordinates = pd.DataFrame(coordinates, columns = ['Latitude', 'Longitude'])
df_se_loc['Latitude'] = df_se_coordinates['Latitude']
df_se_loc['Longitude'] = df_se_coordinates['Longitude']

# %%
df_se_loc.head(5)
# Out:
#        Location    Borough Postcode  Latitude  Longitude
# 0  Crofton Park   Lewisham      SE4  51.46268   -0.03558
# 1  Denmark Hill  Southwark      SE5  51.47480   -0.09313
# 2      Deptford   Lewisham      SE8  51.48114   -0.02467
# 3       Dulwich  Southwark     SE21  51.44100   -0.08897
# 4  East Dulwich  Southwark     SE22  51.45256   -0.07076

# %%
df_se_loc.to_csv('SELondonLocationsCoordinates.csv', index = False)

# %%
df_se_loc.shape
# Out:
# (46, 5)

# %% [markdown]
# 2.1.3 Dataset 3:
#
# The Foursquare API will be used to obtain the South East London Area venues for the geographical location data . These will be used to explore the neighbourhoods of London acordingly.
#
# The venues within the neighbourhoods of South East London like the areas's restaurants and proximity to amenities would be correlated. Also, accessibility and ease of supplies would be considered as it relates to venues.
#
# To use the Foursquare API, we define the Foursquare Credentials and Version as shown below:
#
# Please note that due to privacy, the personal Foursquare Credential has been stored in a .json <fsquarecredential.json> and called appropriately as shown below:

# %%
CLIENT_ID = 'C444MKEBPBXBMJI4AQTKTNSFBGIJOXDMTK0ORN53MVWSF05K' # your Foursquare ID
CLIENT_SECRET = 'MWCZCPELAV32RTPUHFPLQSRZFUWULS1MUNYDHMZNG2BKTP5I' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: C444MKEBPBXBMJI4AQTKTNSFBGIJOXDMTK0ORN53MVWSF05K
# CLIENT_SECRET:MWCZCPELAV32RTPUHFPLQSRZFUWULS1MUNYDHMZNG2BKTP5I

# %% [markdown]
# 3. Methodology¶
# 3.1 Data Exploration
# 3.1.1 Single Neighbourhood
#
# An initial exploration of a single Neighbourhood within the London area was done to examine the Foursquare workability. The Lewisham Borough postcode SE13 and Location - Lewisham is used for this.

# %%
se_df = df_se_loc.reset_index().drop('index', axis = 1)

# %%
se_df.shape
# Out:
# (46, 5)

# %%
se_df
# Out:
#                Location    Borough Postcode  Latitude  Longitude
# 0          Crofton Park   Lewisham      SE4  51.46268   -0.03558
# 1          Denmark Hill  Southwark      SE5  51.47480   -0.09313
# 2              Deptford   Lewisham      SE8  51.48114   -0.02467
# 3               Dulwich  Southwark     SE21  51.44100   -0.08897
# 4          East Dulwich  Southwark     SE22  51.45256   -0.07076
# 5   Elephant and Castle  Southwark      SE1  51.49960   -0.09613
# 6   Elephant and Castle  Southwark     SE11  51.49084   -0.11108
# 7   Elephant and Castle  Southwark     SE17  51.48764   -0.09542
# 8              Bankside  Southwark      SE1  51.49960   -0.09613
# 9           Forest Hill   Lewisham     SE23  51.44122   -0.04764
# 10           Gipsy Hill    Lambeth     SE19  51.41990   -0.08808
# 11           Gipsy Hill    Lambeth     SE27  51.43407   -0.10375
# 12           Grove Park   Lewisham     SE12  51.44759    0.01350
# 13           Herne Hill    Lambeth     SE24  51.45529   -0.09928
# 14         Hither Green   Lewisham     SE13  51.46196   -0.00754
# 15            Honor Oak   Lewisham     SE23  51.44122   -0.04764
# 16             Ladywell   Lewisham      SE4  51.46268   -0.03558
# 17             Ladywell   Lewisham     SE13  51.46196   -0.00754
# 18              Lambeth    Lambeth      SE1  51.49960   -0.09613
# 19                  Lee   Lewisham     SE12  51.44759    0.01350
# 20             Lewisham   Lewisham     SE13  51.46196   -0.00754
# 21            New Cross   Lewisham     SE14  51.47489   -0.04038
# 22            Newington  Southwark      SE1  51.49960   -0.09613
# 23            Newington  Southwark     SE17  51.48764   -0.09542
# 24              Nunhead  Southwark     SE15  51.47218   -0.06779
# 25                 Oval    Lambeth     SE11  51.49084   -0.11108
# 26           Bellingham   Lewisham      SE6  51.43722   -0.01868
# 27              Peckham  Southwark     SE15  51.47218   -0.06779
# 28          Rotherhithe  Southwark     SE16  51.49574   -0.05157
# 29             Selhurst    Croydon     SE25  51.39925   -0.07414
# 30           Bermondsey  Southwark      SE1  51.49960   -0.09613
# 31        South Norwood    Croydon     SE25  51.39925   -0.07414
# 32             Southend   Lewisham      SE6  51.43722   -0.01868
# 33             St Johns   Lewisham      SE4  51.46268   -0.03558
# 34         Surrey Quays  Southwark     SE16  51.49574   -0.05157
# 35           Tulse Hill    Lambeth     SE24  51.45529   -0.09928
# 36           Tulse Hill    Lambeth     SE27  51.43407   -0.10375
# 37        Upper Norwood    Croydon     SE19  51.41990   -0.08808
# 38             Walworth  Southwark     SE17  51.48764   -0.09542
# 39           Blackheath   Lewisham      SE3  51.47138    0.02338
# 40         West Norwood    Lambeth     SE27  51.43407   -0.10375
# 41              Brixton    Lambeth      SE5  51.47480   -0.09313
# 42             Brockley   Lewisham      SE4  51.46268   -0.03558
# 43           Camberwell  Southwark      SE5  51.47480   -0.09313
# 44              Catford   Lewisham      SE6  51.43722   -0.01868
# 45            Chinbrook   Lewisham     SE12  51.44759    0.01350

# %%
se_df.loc[se_df['Location'] == 'Lewisham']
# Out:
#     Location   Borough Postcode  Latitude  Longitude
# 20  Lewisham  Lewisham     SE13  51.46196   -0.00754

# %%
se_df.loc[20, 'Location']
# Out:
# 'Lewisham'

# %%
lewisham_lat = se_df.loc[20, 'Latitude']
lewisham_long = se_df.loc[20, 'Longitude']
lewisham_loc = se_df.loc[20, 'Location']
lewisham_postcode = se_df.loc[20, 'Postcode']

print('The latitude and longitude values of {} with postcode {}, are {}, {}.'.format(lewisham_loc,
                                                                                         lewisham_postcode,
                                                                                         lewisham_lat,
                                                                                         lewisham_long))
# Out:
# The latitude and longitude values of Lewisham with postcode SE13, are 51.46196000000003, -0.007539999999949032.

# %%
# Credentials are provided already for this part
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 2000 # define radius
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    lewisham_lat, 
    lewisham_long, 
    radius, 
    LIMIT)

# displays URL
url

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d2430b4d29cbb1d389ed175'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Lewisham Central',
#   'headerFullLocation': 'Lewisham Central, London',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 184,
#   'suggestedBounds': {'ne': {'lat': 51.47996001800005,
#     'lng': 0.021296961190459426},
#    'sw': {'lat': 51.44395998200002, 'lng': -0.03637696119035749}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '535823bc498ec8d8da9aad5f',
#        'name': 'Street Feast Model Market',
#        'location': {'address': '196 Lewisham High St',
#         'crossStreet': 'entrance at Molesworth St',
#         'lat': 51.46020945743763,
#         'lng': -0.012199022914877357,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.46020945743763,
#           'lng': -0.012199022914877357}],
#         'distance': 377,
#         'postalCode': 'SE13 6LS',
#         'cc': 'GB',
#         'neighborhood': 'Lewisham Central, London, Greater London',
#         'city': 'Lewisham Central',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['196 Lewisham High St (entrance at Molesworth St)',
#          'Lewisham Central',
#          'Greater London',
#          'SE13 6LS',
#          'United Kingdom']},
#        'categories': [{'id': '53e0feef498e5aac066fd8a9',
#          'name': 'Street Food Gathering',
#          'pluralName': 'Street Food Gatherings',
#          'shortName': 'Street Food Gathering',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-535823bc498ec8d8da9aad5f-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b640ce6f964a520ee9c2ae3',
#        'name': 'Levante restaurant',
#        'location': {'address': '11 Lewis Grove',
#         'crossStreet': 'Belmont Hill',
#         'lat': 51.46207211451613,
#         'lng': -0.009490926926344812,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.46207211451613,
#           'lng': -0.009490926926344812}],
#         'distance': 135,
#         'postalCode': 'SE13  BG',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['11 Lewis Grove (Belmont Hill)',
#          'Lewisham',
#          'Greater London',
#          'SE13  BG',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b640ce6f964a520ee9c2ae3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd2b69377b29c7434478f82',
#        'name': "Maggie's Kitchen",
#        'location': {'address': '320-322 Lewisham Rd.',
#         'lat': 51.46537957272932,
#         'lng': -0.011213018572287086,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.46537957272932,
#           'lng': -0.011213018572287086}],
#         'distance': 458,
#         'postalCode': 'SE13 7PA',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['320-322 Lewisham Rd.',
#          'Lewisham',
#          'Greater London',
#          'SE13 7PA',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd2b69377b29c7434478f82-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d56efce9e508cfa8dee149b',
#        'name': 'Levante Pide Restaurant',
#        'location': {'address': '187 Lewisham High St',
#         'lat': 51.459848264113056,
#         'lng': -0.011476481770328631,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.459848264113056,
#           'lng': -0.011476481770328631}],
#         'distance': 360,
#         'postalCode': 'SE13 6AA',
#         'cc': 'GB',
#         'neighborhood': 'Lewisham Central',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['187 Lewisham High St',
#          'Lewisham',
#          'Greater London',
#          'SE13 6AA',
#          'United Kingdom']},
#        'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#          'name': 'Turkish Restaurant',
#          'pluralName': 'Turkish Restaurants',
#          'shortName': 'Turkish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d56efce9e508cfa8dee149b-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c66be678e9120a1ecb3d864',
#        'name': 'Gennaro Delicatessan',
#        'location': {'address': '23 Lewis Grove',
#         'lat': 51.4617645065367,
#         'lng': -0.009725767238995344,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.4617645065367,
#           'lng': -0.009725767238995344}],
#         'distance': 153,
#         'postalCode': 'SE13 6BG',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['23 Lewis Grove',
#          'Lewisham',
#          'Greater London',
#          'SE13 6BG',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c66be678e9120a1ecb3d864-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b3e9b40f964a520a99f25e3',
#        'name': 'Manor House Gardens',
#        'location': {'address': 'Old Rd',
#         'crossStreet': 'Aislibie Rd',
#         'lat': 51.45668630808165,
#         'lng': 0.004684430062631204,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.45668630808165,
#           'lng': 0.004684430062631204}],
#         'distance': 1031,
#         'postalCode': 'S E12',
#         'cc': 'GB',
#         'neighborhood': 'Lee Green',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Old Rd (Aislibie Rd)',
#          'Lewisham',
#          'Greater London',
#          'S E12',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b3e9b40f964a520a99f25e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '512c80cbe4b0a7144ed5dc7a',
#        'name': 'Corte',
#        'location': {'address': '189 Lewisham High St',
#         'lat': 51.45977605027753,
#         'lng': -0.01155377601146681,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.45977605027753,
#           'lng': -0.01155377601146681}],
#         'distance': 369,
#         'postalCode': 'SE13 6AA',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['189 Lewisham High St',
#          'Lewisham',
#          'Greater London',
#          'SE13 6AA',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-512c80cbe4b0a7144ed5dc7a-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50a10407498efdffc82b15a7',
#        'name': 'Everest Curry King',
#        'location': {'address': '24 Loampit Hill',
#         'lat': 51.466011610245914,
#         'lng': -0.019656034700388247,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.466011610245914,
#           'lng': -0.019656034700388247}],
#         'distance': 953,
#         'postalCode': 'SE13 7SW',
#         'cc': 'GB',
#         'city': 'Lewisham Central',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['24 Loampit Hill',
#          'Lewisham Central',
#          'Greater London',
#          'SE13 7SW',
#          'United Kingdom']},
#        'categories': [{'id': '5413605de4b0ae91d18581a9',
#          'name': 'Sri Lankan Restaurant',
#          'pluralName': 'Sri Lankan Restaurants',
#          'shortName': 'Sri Lankan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50a10407498efdffc82b15a7-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b52d617f964a520fa8827e3',
#        'name': "Blackheath Farmers' Market",
#        'location': {'address': 'Blackheath Village',
#         'lat': 51.46591346191698,
#         'lng': 0.007945118368659382,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.46591346191698,
#           'lng': 0.007945118368659382}],
#         'distance': 1160,
#         'cc': 'GB',
#         'city': 'Blackheath',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Blackheath Village',
#          'Blackheath',
#          'Greater London',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1fa941735',
#          'name': 'Farmers Market',
#          'pluralName': 'Farmers Markets',
#          'shortName': "Farmer's Market",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b52d617f964a520fa8827e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50c5e8e8e4b049cab1a7a58b',
#        'name': 'Côte Brasserie',
#        'location': {'address': '15-16 Royal Parade',
#         'lat': 51.4673781623608,
#         'lng': 0.00717625771325699,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.4673781623608,
#           'lng': 0.00717625771325699}],
#         'distance': 1185,
#         'postalCode': 'SE3 0TL',
#         'cc': 'GB',
#         'city': 'Blackheath',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['15-16 Royal Parade',
#          'Blackheath',
#          'Greater London',
#          'SE3 0TL',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50c5e8e8e4b049cab1a7a58b-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50afc7b4e4b00b39bcbc8e81',
#        'name': 'Budget Gym Lewisham',
#        'location': {'lat': 51.46268658170428,
#         'lng': -0.009891260630664714,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.46268658170428,
#           'lng': -0.009891260630664714}],
#         'distance': 182,
#         'cc': 'GB',
#         'country': 'United Kingdom',
#         'formattedAddress': ['United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50afc7b4e4b00b39bcbc8e81-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4afd75a5f964a520f42722e3',
#        'name': 'Hilly Fields',
#        'location': {'address': 'Adelaide Ave',
#         'crossStreet': 'Montague Ave',
#         'lat': 51.46001017998527,
#         'lng': -0.025599002838134766,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.46001017998527,
#           'lng': -0.025599002838134766}],
#         'distance': 1271,
#         'postalCode': 'SE13 7JL',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Adelaide Ave (Montague Ave)',
#          'London',
#          'Greater London',
#          'SE13 7JL',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4afd75a5f964a520f42722e3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9ba052f964a520a21436e3',
#        'name': 'Buenos Aires Cafe',
#        'location': {'address': '17 Royal Parade',
#         'lat': 51.46725985290514,
#         'lng': 0.007082625289599424,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.46725985290514,
#           'lng': 0.007082625289599424}],
#         'distance': 1173,
#         'postalCode': 'SE3 0TL',
#         'cc': 'GB',
#         'city': 'Blackheath',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['17 Royal Parade',
#          'Blackheath',
#          'Greater London',
#          'SE3 0TL',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d107941735',
#          'name': 'Argentinian Restaurant',
#          'pluralName': 'Argentinian Restaurants',
#          'shortName': 'Argentinian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9ba052f964a520a21436e3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5a0112f964a52015a728e3',
#        'name': "Cafe Oscar's",
#        'location': {'address': '48 Ladywell Rd',
#         'lat': 51.45643221889006,
#         'lng': -0.020194217958707968,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.45643221889006,
#           'lng': -0.020194217958707968}],
#         'distance': 1071,
#         'postalCode': 'SE13 7UX',
#         'cc': 'GB',
#         'city': 'Ladywell',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['48 Ladywell Rd',
#          'Ladywell',
#          'Greater London',
#          'SE13 7UX',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5a0112f964a52015a728e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc5c1334a9aa5939cd8067b',
#        'name': 'The Sausage Man',
#        'location': {'address': '90-98 Lewisham High St',
#         'lat': 51.46250733182629,
#         'lng': -0.01024845973388549,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.46250733182629,
#           'lng': -0.01024845973388549}],
#         'distance': 197,
#         'postalCode': 'SE1 3 6',
#         'cc': 'GB',
#         'neighborhood': 'Lewisham Central',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['90-98 Lewisham High St',
#          'Lewisham',
#          'Greater London',
#          'SE1 3 6',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1cb941735',
#          'name': 'Food Truck',
#          'pluralName': 'Food Trucks',
#          'shortName': 'Food Truck',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc5c1334a9aa5939cd8067b-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac518c7f964a52053a520e3',
#        'name': 'Dirty South',
#        'location': {'address': '162 Lee High Rd',
#         'lat': 51.458846296121216,
#         'lng': -0.0026656179995295853,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.458846296121216,
#           'lng': -0.0026656179995295853}],
#         'distance': 484,
#         'postalCode': 'SE13 5PR',
#         'cc': 'GB',
#         'neighborhood': 'Lewisham',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['162 Lee High Rd',
#          'Lewisham',
#          'Greater London',
#          'SE13 5PR',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ac518c7f964a52053a520e3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e86edff30f80c7d3c4e860a',
#        'name': 'Brockley Market',
#        'location': {'address': 'Lewisham College Car Park',
#         'crossStreet': 'at Lewisham Way',
#         'lat': 51.46798006889389,
#         'lng': -0.02479471423941355,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.46798006889389,
#           'lng': -0.02479471423941355}],
#         'distance': 1371,
#         'postalCode': 'SE4 1UT',
#         'cc': 'GB',
#         'city': 'Brockley',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Lewisham College Car Park (at Lewisham Way)',
#          'Brockley',
#          'Greater London',
#          'SE4 1UT',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1fa941735',
#          'name': 'Farmers Market',
#          'pluralName': 'Farmers Markets',
#          'shortName': "Farmer's Market",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e86edff30f80c7d3c4e860a-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '537656b3498e037ae8680093',
#        'name': 'Le Bouchon Wine Bar',
#        'location': {'address': '72 Tranquil Vale',
#         'lat': 51.46700433291752,
#         'lng': 0.007066931667159507,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.46700433291752,
#           'lng': 0.007066931667159507}],
#         'distance': 1158,
#         'cc': 'GB',
#         'city': 'Blackheath',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['72 Tranquil Vale',
#          'Blackheath',
#          'Greater London',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-537656b3498e037ae8680093-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fd338e2e4b008dc35caa166',
#        'name': 'Pistachios In The Park',
#        'location': {'address': 'Hilly Fields',
#         'lat': 51.46014387411361,
#         'lng': -0.02426326274871826,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.46014387411361,
#           'lng': -0.02426326274871826}],
#         'distance': 1177,
#         'postalCode': 'SE4 1LR',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Hilly Fields',
#          'London',
#          'Greater London',
#          'SE4 1LR',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fd338e2e4b008dc35caa166-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b08f77ef964a5209e1323e3',
#        'name': 'Ladywell Tavern',
#        'location': {'address': '80 Ladywell Rd',
#         'lat': 51.45648457338962,
#         'lng': -0.021502305521404072,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.45648457338962,
#           'lng': -0.021502305521404072}],
#         'distance': 1144,
#         'postalCode': 'SE13 7HS',
#         'cc': 'GB',
#         'city': 'Ladywell',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['80 Ladywell Rd',
#          'Ladywell',
#          'Greater London',
#          'SE13 7HS',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b08f77ef964a5209e1323e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba388c8f964a520294538e3',
#        'name': 'The Spice Of Life',
#        'location': {'address': '260 Lee High Rd',
#         'lat': 51.458654,
#         'lng': 0.002613,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.458654,
#           'lng': 0.002613}],
#         'distance': 794,
#         'postalCode': 'SE13 5PL',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['260 Lee High Rd',
#          'London',
#          'Greater London',
#          'SE13 5PL',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba388c8f964a520294538e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f4e8a08e4b052b87c1a5d0e',
#        'name': 'Ladywell Fields',
#        'location': {'address': 'Ladywell',
#         'lat': 51.45357902994656,
#         'lng': -0.020084381103515625,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.45357902994656,
#           'lng': -0.020084381103515625}],
#         'distance': 1275,
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Ladywell',
#          'London',
#          'Greater London',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f4e8a08e4b052b87c1a5d0e-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e9ad137dab4d1d4ac39f3a2',
#        'name': 'Dark Fluid',
#        'location': {'address': 'Brockley Market',
#         'lat': 51.46798078057207,
#         'lng': -0.024662132312665935,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.46798078057207,
#           'lng': -0.024662132312665935}],
#         'distance': 1363,
#         'postalCode': 'SE4 1UT',
#         'cc': 'GB',
#         'city': 'Brockley',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Brockley Market',
#          'Brockley',
#          'Greater London',
#          'SE4 1UT',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1cb941735',
#          'name': 'Food Truck',
#          'pluralName': 'Food Trucks',
#          'shortName': 'Food Truck',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e9ad137dab4d1d4ac39f3a2-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '580b9ebed67c3294601813df',
#        'name': 'Asda',
#        'location': {'address': 'Thurston Rd',
#         'lat': 51.46513597465588,
#         'lng': -0.01659912305670958,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.46513597465588,
#           'lng': -0.01659912305670958}],
#         'distance': 720,
#         'postalCode': 'SE13 7SD',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Thurston Rd',
#          'Lewisham',
#          'Greater London',
#          'SE13 7SD',
#          'United Kingdom']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-580b9ebed67c3294601813df-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '548031d4498e47562a4fb132',
#        'name': "GAIL's Bakery",
#        'location': {'address': '3 Blackheath Village',
#         'lat': 51.46569561377268,
#         'lng': 0.009166128401830731,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.46569561377268,
#           'lng': 0.009166128401830731}],
#         'distance': 1230,
#         'postalCode': 'SE3 9LA',
#         'cc': 'GB',
#         'city': 'Blackheath',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['3 Blackheath Village',
#          'Blackheath',
#          'Greater London',
#          'SE3 9LA',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-548031d4498e47562a4fb132-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac518d2f964a5202fa720e3',
#        'name': 'Blackheath Common',
#        'location': {'address': 'Shooters Hill Rd',
#         'lat': 51.47232176631012,
#         'lng': 0.007381439208984375,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.47232176631012,
#           'lng': 0.007381439208984375}],
#         'distance': 1549,
#         'postalCode': 'SE3 0TY',
#         'cc': 'GB',
#         'city': 'Blackheath',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Shooters Hill Rd',
#          'Blackheath',
#          'Greater London',
#          'SE3 0TY',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ac518d2f964a5202fa720e3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5582c65a498e17ab80f192ed',
#        'name': 'ARTsCAFE',
#        'location': {'address': 'Manor Park',
#         'lat': 51.45614123650728,
#         'lng': -0.002963840961456299,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.45614123650728,
#           'lng': -0.002963840961456299}],
#         'distance': 721,
#         'postalCode': 'SE13 5QZ',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Manor Park',
#          'London',
#          'Greater London',
#          'SE13 5QZ',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5582c65a498e17ab80f192ed-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4daf305b43a1e3d9e64083a5',
#        'name': 'The Point Greenwich',
#        'location': {'address': 'Point Hill',
#         'lat': 51.47320163063712,
#         'lng': -0.00929281936065029,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.47320163063712,
#           'lng': -0.00929281936065029}],
#         'distance': 1257,
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Point Hill',
#          'London',
#          'Greater London',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4daf305b43a1e3d9e64083a5-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57c5dd14498e8d1389684ad6',
#        'name': 'The Brookmill',
#        'location': {'address': '65 Cranbrook Road',
#         'lat': 51.4708490045668,
#         'lng': -0.02186938195121117,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.4708490045668,
#           'lng': -0.02186938195121117}],
#         'distance': 1402,
#         'postalCode': 'SE8 4EJ',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['65 Cranbrook Road',
#          'London',
#          'Greater London',
#          'SE8 4EJ',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57c5dd14498e8d1389684ad6-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc9d8eb937ca593e96aa692',
#        'name': 'Greenwich Park',
#        'location': {'address': 'Maze Hill',
#         'crossStreet': 'Charlton Way',
#         'lat': 51.47752077622347,
#         'lng': 0.000858306884765625,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.47752077622347,
#           'lng': 0.000858306884765625}],
#         'distance': 1827,
#         'postalCode': 'SE10 9NF',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Maze Hill (Charlton Way)',
#          'Greenwich',
#          'Greater London',
#          'SE10 9NF',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc9d8eb937ca593e96aa692-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c03db5739d476b0769e30a7',
#        'name': 'Peter Harrison Planetarium',
#        'location': {'address': 'Blackheath Ave',
#         'lat': 51.47711483373106,
#         'lng': -0.0007537007331848145,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.47711483373106,
#           'lng': -0.0007537007331848145}],
#         'distance': 1751,
#         'postalCode': 'SE10 8XJ',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Blackheath Ave',
#          'Greenwich',
#          'Greater London',
#          'SE10 8XJ',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d192941735',
#          'name': 'Planetarium',
#          'pluralName': 'Planetariums',
#          'shortName': 'Planetarium',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_planetarium_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c03db5739d476b0769e30a7-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbccb33f57ba593eb3fadb9',
#        'name': 'Golden Chippy',
#        'location': {'address': '62 Greenwich High Road',
#         'lat': 51.475991562067,
#         'lng': -0.018594816686180994,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.475991562067,
#           'lng': -0.018594816686180994}],
#         'distance': 1739,
#         'postalCode': 'SE10 8LF',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['62 Greenwich High Road',
#          'London',
#          'SE10 8LF',
#          'United Kingdom']},
#        'categories': [{'id': '4edd64a0c7ddd24ca188df1a',
#          'name': 'Fish & Chips Shop',
#          'pluralName': 'Fish & Chips Shops',
#          'shortName': 'Fish & Chips',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fishandchips_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbccb33f57ba593eb3fadb9-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '513b3367e4b0cc279efb7461',
#        'name': 'Spit And Roast',
#        'location': {'address': 'Brockley Market',
#         'crossStreet': 'at Lewisham Way',
#         'lat': 51.466137689772246,
#         'lng': -0.01961804498070766,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.466137689772246,
#           'lng': -0.01961804498070766}],
#         'distance': 958,
#         'postalCode': 'SE4',
#         'cc': 'GB',
#         'city': 'Brockley',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Brockley Market (at Lewisham Way)',
#          'Brockley',
#          'Greater London',
#          ' SE4',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1cb941735',
#          'name': 'Food Truck',
#          'pluralName': 'Food Trucks',
#          'shortName': 'Food Truck',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-513b3367e4b0cc279efb7461-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fc54bc6e4b01ac8e1df0409',
#        'name': 'Greenwich Park Flower Garden',
#        'location': {'address': 'Bower Ave',
#         'lat': 51.475983324676235,
#         'lng': 0.0052708537344745374,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.475983324676235,
#           'lng': 0.0052708537344745374}],
#         'distance': 1796,
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Bower Ave',
#          'London',
#          'Greater London',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d15a941735',
#          'name': 'Garden',
#          'pluralName': 'Gardens',
#          'shortName': 'Garden',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fc54bc6e4b01ac8e1df0409-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b40f6c3f964a5205ebe25e3',
#        'name': 'The Greenwich Union',
#        'location': {'address': '56 Royal Hill',
#         'crossStreet': 'at Hyde Vale',
#         'lat': 51.47658700278182,
#         'lng': -0.009841797114849388,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.47658700278182,
#           'lng': -0.009841797114849388}],
#         'distance': 1636,
#         'postalCode': 'SE10 8RT',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['56 Royal Hill (at Hyde Vale)',
#          'Greenwich',
#          'Greater London',
#          'SE10 8RT',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b40f6c3f964a5205ebe25e3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e9c655cb63497cdaa96ce75',
#        'name': 'Greenwich Meridian',
#        'location': {'address': 'Blackheath Ave',
#         'lat': 51.47791502144104,
#         'lng': -0.0015288591384887695,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.47791502144104,
#           'lng': -0.0015288591384887695}],
#         'distance': 1824,
#         'postalCode': 'SE10 8XJ',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Blackheath Ave',
#          'London',
#          'Greater London',
#          'SE10 8XJ',
#          'United Kingdom']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e9c655cb63497cdaa96ce75-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52ab7152498ed9c9cd5b9bbf',
#        'name': 'Meze Mangal',
#        'location': {'address': '245 Lewisham Way',
#         'lat': 51.46949340691928,
#         'lng': -0.02765590551113475,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.46949340691928,
#           'lng': -0.02765590551113475}],
#         'distance': 1627,
#         'postalCode': 'SE4 1XF',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['245 Lewisham Way',
#          'Brockley',
#          'Greater London',
#          'SE4 1XF',
#          'United Kingdom']},
#        'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#          'name': 'Turkish Restaurant',
#          'pluralName': 'Turkish Restaurants',
#          'shortName': 'Turkish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52ab7152498ed9c9cd5b9bbf-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f01f98ee5faf2869dbda72c',
#        'name': "Brockley's Rock",
#        'location': {'address': '317 Brockley Rd',
#         'lat': 51.459456802443434,
#         'lng': -0.033867936509008774,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.459456802443434,
#           'lng': -0.033867936509008774}],
#         'distance': 1847,
#         'postalCode': 'SE4 2QZ',
#         'cc': 'GB',
#         'city': 'Brockley',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['317 Brockley Rd',
#          'Brockley',
#          'Greater London',
#          'SE4 2QZ',
#          'United Kingdom']},
#        'categories': [{'id': '4edd64a0c7ddd24ca188df1a',
#          'name': 'Fish & Chips Shop',
#          'pluralName': 'Fish & Chips Shops',
#          'shortName': 'Fish & Chips',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fishandchips_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f01f98ee5faf2869dbda72c-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b2fe171f964a520e1f124e3',
#        'name': 'Princess of Wales',
#        'location': {'address': '1a Montpeller Row',
#         'lat': 51.46933398020491,
#         'lng': 0.010359506816897507,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.46933398020491,
#           'lng': 0.010359506816897507}],
#         'distance': 1488,
#         'postalCode': 'SE3 0RL',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
# ...
#        'name': 'Montpeliers',
#        'location': {'address': 'Montpelier Vale',
#         'lat': 51.46750849674762,
#         'lng': 0.008476527003615415,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.46750849674762,
#           'lng': 0.008476527003615415}],
#         'distance': 1270,
#         'postalCode': 'SE3',
#         'cc': 'GB',
#         'city': 'Blackheath',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Montpelier Vale',
#          'Blackheath',
#          'Greater London',
#          ' SE3',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b55ba89f964a5206eed27e3-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51fce879498e1f006da0ee22',
#        'name': 'Brockley Brewery (The Brockley Brewing Company)',
#        'location': {'address': '31 Harcourt Rd',
#         'lat': 51.46226467810521,
#         'lng': -0.03613224829342145,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.46226467810521,
#           'lng': -0.03613224829342145}],
#         'distance': 1983,
#         'postalCode': 'SE4 2RJ',
#         'cc': 'GB',
#         'city': 'Brockley',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['31 Harcourt Rd',
#          'Brockley',
#          'Greater London',
#          'SE4 2RJ',
#          'United Kingdom']},
#        'categories': [{'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'shortName': 'Brewery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51fce879498e1f006da0ee22-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c4c5bb65609c9b614986a92',
#        'name': 'The Junk Shop',
#        'location': {'address': '9 Greenwich South St',
#         'lat': 51.47771151463596,
#         'lng': -0.012022450873061329,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.47771151463596,
#           'lng': -0.012022450873061329}],
#         'distance': 1780,
#         'postalCode': 'SE10 8NW',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['9 Greenwich South St',
#          'Greenwich',
#          'Greater London',
#          'SE10 8NW',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d101951735',
#          'name': 'Thrift / Vintage Store',
#          'pluralName': 'Thrift / Vintage Stores',
#          'shortName': 'Thrift / Vintage',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c4c5bb65609c9b614986a92-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b33dc09f964a520bd2025e3',
#        'name': 'The Talbot',
#        'location': {'address': '2 Tyrwhitt Rd',
#         'lat': 51.467257284567154,
#         'lng': -0.023486667132346727,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.467257284567154,
#           'lng': -0.023486667132346727}],
#         'distance': 1253,
#         'postalCode': 'SE4 1QG',
#         'cc': 'GB',
#         'city': 'Brockley',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['2 Tyrwhitt Rd',
#          'Brockley',
#          'Greater London',
#          'SE4 1QG',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d155941735',
#          'name': 'Gastropub',
#          'pluralName': 'Gastropubs',
#          'shortName': 'Gastropub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b33dc09f964a520bd2025e3-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c5709f2744a0f47b60dc8cb',
#        'name': 'OneSE8 Gym',
#        'location': {'address': 'Indiana Building, Deals Gateway',
#         'lat': 51.47286594168999,
#         'lng': -0.021289135038009,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.47286594168999,
#           'lng': -0.021289135038009}],
#         'distance': 1543,
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Indiana Building, Deals Gateway',
#          'London',
#          'Greater London',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c5709f2744a0f47b60dc8cb-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ebeb19961af06192abe1d62',
#        'name': 'Greenwich Picturehouse Bar',
#        'location': {'address': '180 Greenwich High Road',
#         'lat': 51.479523016991436,
#         'lng': -0.0098599250338723,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.479523016991436,
#           'lng': -0.0098599250338723}],
#         'distance': 1961,
#         'postalCode': 'SE10 8NN',
#         'cc': 'GB',
#         'neighborhood': 'Greenwich West',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['180 Greenwich High Road',
#          'Greenwich',
#          'Greater London',
#          'SE10 8NN',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ebeb19961af06192abe1d62-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e259cbbd164b6b74afc6b02',
#        'name': 'General James Wolfe Statue',
#        'location': {'address': 'Blackheath Ave',
#         'lat': 51.47784652993174,
#         'lng': -0.0008180737495422362,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.47784652993174,
#           'lng': -0.0008180737495422362}],
#         'distance': 1828,
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Blackheath Ave',
#          'Greenwich',
#          'Greater London',
#          'United Kingdom']},
#        'categories': [{'id': '52e81612bcbc57f1066b79ed',
#          'name': 'Outdoor Sculpture',
#          'pluralName': 'Outdoor Sculptures',
#          'shortName': 'Outdoor Sculpture',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sculpture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e259cbbd164b6b74afc6b02-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6d45b3f964a520a16e2ce3',
#        'name': 'Blackheath Tea Hut',
#        'location': {'address': 'Shooters Hill',
#         'crossStreet': 'Goffers Road',
#         'lat': 51.471802478594846,
#         'lng': -0.00010007742361862107,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.471802478594846,
#           'lng': -0.00010007742361862107}],
#         'distance': 1211,
#         'postalCode': 'SE3 0TY',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Shooters Hill (Goffers Road)',
#          'London',
#          'Greater London',
#          'SE3 0TY',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6d45b3f964a520a16e2ce3-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd46aab7b1876b0faee8886',
#        'name': 'Guildford Arms',
#        'location': {'address': '55 Guildford Grove',
#         'crossStreet': 'at Devonshire Dr.',
#         'lat': 51.47440596985897,
#         'lng': -0.014960813781301222,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.47440596985897,
#           'lng': -0.014960813781301222}],
#         'distance': 1477,
#         'postalCode': 'SE10 8JY',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['55 Guildford Grove (at Devonshire Dr.)',
#          'Greenwich',
#          'Greater London',
#          'SE10 8JY',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd46aab7b1876b0faee8886-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53956ede498ecef18324fb8f',
#        'name': 'Staycity Aparthotels Deptford Bridge Station',
#        'location': {'address': '18-20 Deptford Bridge',
#         'lat': 51.47425942693647,
#         'lng': -0.023101651491559905,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.47425942693647,
#           'lng': -0.023101651491559905}],
#         'distance': 1743,
#         'postalCode': 'SE8 4HH',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['18-20 Deptford Bridge',
#          'London',
#          'Greater London',
#          'SE8 4HH',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53956ede498ecef18324fb8f-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c991caf78fc236a01262a97',
#        'name': 'Carola',
#        'location': {'address': '151 Lee Rd.',
#         'lat': 51.45674131056459,
#         'lng': 0.0113766869923377,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.45674131056459,
#           'lng': 0.0113766869923377}],
#         'distance': 1434,
#         'postalCode': 'SE3 9DJ',
#         'cc': 'GB',
#         'neighborhood': 'Blackheath',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['151 Lee Rd.',
#          'Lewisham',
#          'Greater London',
#          'SE3 9DJ',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c991caf78fc236a01262a97-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ce7fbe3d99f721eac8cad73',
#        'name': 'Greenwich Tavern',
#        'location': {'address': '1 King William Walk',
#         'crossStreet': 'Nevada St',
#         'lat': 51.47981937831838,
#         'lng': -0.007156133651733398,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.47981937831838,
#           'lng': -0.007156133651733398}],
#         'distance': 1988,
#         'postalCode': 'SE10 9JH',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['1 King William Walk (Nevada St)',
#          'Greenwich',
#          'Greater London',
#          'SE10 9JH',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ce7fbe3d99f721eac8cad73-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac518e9f964a520bfab20e3',
#        'name': 'Blackheath Halls',
#        'location': {'address': '23 Lee Road',
#         'lat': 51.464380163764666,
#         'lng': 0.009570343783047292,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.464380163764666,
#           'lng': 0.009570343783047292}],
#         'distance': 1216,
#         'postalCode': 'SE3 9RQ',
#         'cc': 'GB',
#         'city': 'London',
#         'state': 'Greater London',
#         'country': 'United Kingdom',
#         'formattedAddress': ['23 Lee Road',
#          'London',
#          'Greater London',
#          'SE3 9RQ',
#          'United Kingdom']},
#        'categories': [{'id': '5032792091d4c4b30a586d5c',
#          'name': 'Concert Hall',
#          'pluralName': 'Concert Halls',
#          'shortName': 'Concert Hall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ac518e9f964a520bfab20e3-99'}]}]}}

# %% [markdown]
# From the results, the necessary information needs to be obtained from items key. To do this, the get_category_type function is used from the Foursquare lab.

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

# %%
nearby_venues
# Out:
#                                                name  \
# 0                         Street Feast Model Market
# 1                                Levante restaurant
# 2                                  Maggie's Kitchen
# 3                           Levante Pide Restaurant
# 4                              Gennaro Delicatessan
# 5                               Manor House Gardens
# 6                                             Corte
# 7                                Everest Curry King
# 8                        Blackheath Farmers' Market
# 9                                    Côte Brasserie
# 10                              Budget Gym Lewisham
# 11                                     Hilly Fields
# 12                                Buenos Aires Cafe
# 13                                     Cafe Oscar's
# 14                                  The Sausage Man
# 15                                      Dirty South
# 16                                  Brockley Market
# 17                              Le Bouchon Wine Bar
# 18                           Pistachios In The Park
# 19                                  Ladywell Tavern
# 20                                The Spice Of Life
# 21                                  Ladywell Fields
# 22                                       Dark Fluid
# 23                                             Asda
# 24                                    GAIL's Bakery
# 25                                Blackheath Common
# 26                                         ARTsCAFE
# 27                              The Point Greenwich
# 28                                    The Brookmill
# 29                                   Greenwich Park
# 30                       Peter Harrison Planetarium
# 31                                    Golden Chippy
# 32                                   Spit And Roast
# 33                     Greenwich Park Flower Garden
# 34                              The Greenwich Union
# 35                               Greenwich Meridian
# 36                                      Meze Mangal
# 37                                  Brockley's Rock
# 38                                Princess of Wales
# 39                                Royal Observatory
# 40                     Old Royal Observatory Garden
# 41                                   Hand Made Food
# 42                                       Royal Teas
# 43                           Greenwich Picturehouse
# 44                                      Quaggy Café
# 45                                      Full Nelson
# 46                                       McDonald's
# 47                                  Heap's Sausages
# 48                                      London Velo
# 49                                The Station Hotel
# 50                                Richard the First
# 51                                        Le Délice
# 52                                      Panda Panda
# 53                                  Deptford Cinema
# 54                       Greenwich Park Rose Garden
# 55                         The Wilderness Deer Park
# 56                                   The Birds Nest
# 57                         Enish Restaurant + Grill
# 58                                    The Gym Group
# 59                                   The Dacre Arms
# 60                                          Sparrow
# 61                                      The Orchard
# 62                       Greenwich Park Herb Garden
# 63                               The Fox and Firkin
# 64                                      Zerodegrees
# 65                                Greenwich Theatre
# 66                                    Suttons Radio
# 67                                          PureGym
# 68                          The Prince of Greenwich
# 69                        Oliver's Jazz & Piano Bar
# 70                                     Pets at Home
# 71                              Rivington Greenwich
# 72                                  The Creaky Shed
# 73                                         The Hill
# 74                              The Lord Northbrook
# 75                                             Aldi
# 76                                              H&M
# 77                                          TK Maxx
# 78                                        Luciano's
# 79                                    Plumtree Café
# 80                  Everest Inn Gurkha's Restaurant
# 81                       You Don't Bring Me Flowers
# 82                                       Arlo & Moe
# 83                                       The Gantry
# 84                                     Flying Tiger
# 85                                  Something Fishy
# 86            DoubleTree by Hilton London Greenwich
# 87                                      Montpeliers
# 88  Brockley Brewery (The Brockley Brewing Company)
# 89                                    The Junk Shop
# 90                                       The Talbot
# 91                                       OneSE8 Gym
# 92                       Greenwich Picturehouse Bar
# 93                       General James Wolfe Statue
# 94                               Blackheath Tea Hut
# 95                                   Guildford Arms
# 96     Staycity Aparthotels Deptford Bridge Station
# 97                                           Carola
# 98                                 Greenwich Tavern
# 99                                 Blackheath Halls
#
#                        categories        lat       lng
# 0           Street Food Gathering  51.460209 -0.012199
# 1                      Restaurant  51.462072 -0.009491
# 2                            Café  51.465380 -0.011213
# 3              Turkish Restaurant  51.459848 -0.011476
# 4                   Deli / Bodega  51.461765 -0.009726
# 5                            Park  51.456686  0.004684
# 6                     Coffee Shop  51.459776 -0.011554
# 7           Sri Lankan Restaurant  51.466012 -0.019656
# 8                  Farmers Market  51.465913  0.007945
# 9               French Restaurant  51.467378  0.007176
# 10                            Gym  51.462687 -0.009891
# 11                           Park  51.460010 -0.025599
# 12         Argentinian Restaurant  51.467260  0.007083
# 13                    Coffee Shop  51.456432 -0.020194
# 14                     Food Truck  51.462507 -0.010248
# 15                            Pub  51.458846 -0.002666
# 16                 Farmers Market  51.467980 -0.024795
# 17                       Wine Bar  51.467004  0.007067
# 18                           Café  51.460144 -0.024263
# 19                            Pub  51.456485 -0.021502
# 20              Indian Restaurant  51.458654  0.002613
# 21                           Park  51.453579 -0.020084
# 22                     Food Truck  51.467981 -0.024662
# 23                    Supermarket  51.465136 -0.016599
# 24                         Bakery  51.465696  0.009166
# 25                           Park  51.472322  0.007381
# 26                           Café  51.456141 -0.002964
# 27                 Scenic Lookout  51.473202 -0.009293
# 28                            Pub  51.470849 -0.021869
# 29                           Park  51.477521  0.000858
# 30                    Planetarium  51.477115 -0.000754
# 31              Fish & Chips Shop  51.475992 -0.018595
# 32                     Food Truck  51.466138 -0.019618
# 33                         Garden  51.475983  0.005271
# 34                            Pub  51.476587 -0.009842
# 35                  Historic Site  51.477915 -0.001529
# 36             Turkish Restaurant  51.469493 -0.027656
# 37              Fish & Chips Shop  51.459457 -0.033868
# 38                            Pub  51.469334  0.010360
# 39                    Observatory  51.477437 -0.000907
# 40                         Garden  51.477591 -0.001550
# 41                           Café  51.466488  0.008229
# 42                           Café  51.476074 -0.009884
# 43            Indie Movie Theater  51.479619 -0.009778
# 44                           Café  51.471535 -0.014752
# 45  Vegetarian / Vegan Restaurant  51.474779 -0.025149
# 46           Fast Food Restaurant  51.460528 -0.010989
# 47                           Café  51.479516 -0.007875
# 48                    Coffee Shop  51.475413 -0.026005
# 49                      Gastropub  51.453080 -0.000358
# 50                            Pub  51.476614 -0.009756
# 51                         Bakery  51.456610 -0.019732
# 52                 Sandwich Place  51.474800 -0.025123
# 53            Indie Movie Theater  51.474683 -0.024053
# 54                         Garden  51.473685 -0.001137
# 55                    Zoo Exhibit  51.475637  0.007237
# 56                            Pub  51.476203 -0.022738
# 57             African Restaurant  51.459036 -0.012386
# 58                            Gym  51.466384 -0.016964
# 59                            Pub  51.461075  0.003312
# 60                     Restaurant  51.463487 -0.011139
# 61                      Gastropub  51.463678 -0.035699
# 62                         Garden  51.479539 -0.006233
# 63                            Pub  51.456780 -0.014161
# 64                            Bar  51.467417  0.008440
# 65                        Theater  51.479531 -0.007637
# 66                            Pub  51.461011 -0.010554
# 67           Gym / Fitness Center  51.476181 -0.018384
# 68                            Pub  51.476195 -0.009947
# 69                      Jazz Club  51.479458 -0.008096
# 70                      Pet Store  51.472462 -0.016981
# 71                      Gastropub  51.479223 -0.010108
# 72                  Grocery Store  51.477436 -0.009823
# 73                      Gastropub  51.475628 -0.010453
# 74                            Pub  51.450906  0.012225
# 75                    Supermarket  51.448675 -0.017781
# 76                 Clothing Store  51.461367 -0.011812
# 77                 Clothing Store  51.461017 -0.010850
# 78             Italian Restaurant  51.450567  0.012553
# 79                    Coffee Shop  51.478851 -0.010833
# 80              Indian Restaurant  51.467654  0.008438
# 81                    Flower Shop  51.453017 -0.000687
# 82                           Café  51.450235 -0.000094
# 83                      Gastropub  51.463597 -0.036127
# 84                      Gift Shop  51.462198 -0.011849
# 85              Fish & Chips Shop  51.461697 -0.010277
# 86                          Hotel  51.474425 -0.019505
# 87                           Café  51.467508  0.008477
# 88                        Brewery  51.462265 -0.036132
# 89         Thrift / Vintage Store  51.477712 -0.012022
# 90                      Gastropub  51.467257 -0.023487
# 91           Gym / Fitness Center  51.472866 -0.021289
# 92                            Bar  51.479523 -0.009860
# 93              Outdoor Sculpture  51.477847 -0.000818
# 94                 Breakfast Spot  51.471802 -0.000100
# 95                            Pub  51.474406 -0.014961
# 96                          Hotel  51.474259 -0.023102
# 97             Italian Restaurant  51.456741  0.011377
# 98                            Pub  51.479819 -0.007156
# 99                   Concert Hall  51.464380  0.009570

# %%
nearby_venues_lewisham_unique = nearby_venues['categories'].value_counts().to_frame(name='Count')

# %%
nearby_venues_lewisham_unique.head(5)
# Out:
#              Count
# Pub             14
# Café             9
# Gastropub        6
# Park             5
# Coffee Shop      4

# %%
print('{} venues were returned by Foursquare for Lewisham.'.format(nearby_venues.shape[0]))
# Out:
# 100 venues were returned by Foursquare for Lewisham.

# %% [markdown]
# 3.1.2 Multiple Neighbourhoods
#
# Now let's explore (Multiple) Neighborhoods in the South East London area using function getNearbyVenues.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=2000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
se_venues = getNearbyVenues(names=se_df['Location'],
                                   latitudes=se_df['Latitude'],
                                   longitudes=se_df['Longitude']
                                  )
# Out:
# Crofton Park
# Denmark Hill
# Deptford
# Dulwich
# East Dulwich
# Elephant and Castle
# Elephant and Castle
# Elephant and Castle
# Bankside
# Forest Hill
# Gipsy Hill
# Gipsy Hill
# Grove Park
# Herne Hill
# Hither Green
# Honor Oak
# Ladywell
# Ladywell
# Lambeth
# Lee
# Lewisham
# New Cross
# Newington
# Newington
# Nunhead
# Oval
# Bellingham
# Peckham
# Rotherhithe
# Selhurst
# Bermondsey
# South Norwood
# Southend
# St Johns
# Surrey Quays
# Tulse Hill
# Tulse Hill
# Upper Norwood
# Walworth
# Blackheath
# West Norwood
# Brixton
# Brockley
# Camberwell
# Catford
# Chinbrook

# %%
se_venues.shape
# Out:
# (4273, 7)

# %%
se_venues['Neighbourhood'].value_counts()
se_venues.to_csv('se_venues.csv')

# %%
se_venues.head()
# Out:
#   Neighbourhood  Neighbourhood Latitude  Neighbourhood Longitude  \
# 0  Crofton Park                51.46268                 -0.03558
# 1  Crofton Park                51.46268                 -0.03558
# 2  Crofton Park                51.46268                 -0.03558
# 3  Crofton Park                51.46268                 -0.03558
# 4  Crofton Park                51.46268                 -0.03558
#
#                 Venue  Venue Latitude  Venue Longitude     Venue Category
# 0         The Orchard       51.463678        -0.035699          Gastropub
# 1     Brockley's Rock       51.459457        -0.033868  Fish & Chips Shop
# 2           Saka Maka       51.464826        -0.036437  Indian Restaurant
# 3  Browns Of Brockley       51.464513        -0.037346        Coffee Shop
# 4       waterintobeer       51.463712        -0.038826         Beer Store

# %%
se_venues.groupby('Neighbourhood').count()
# Out:
#                      Neighbourhood Latitude  Neighbourhood Longitude  Venue  \
# Neighbourhood
# Bankside                                100                      100    100
# Bellingham                               72                       72     72
# Bermondsey                              100                      100    100
# Blackheath                               94                       94     94
# Brixton                                 100                      100    100
# Brockley                                100                      100    100
# Camberwell                              100                      100    100
# Catford                                  72                       72     72
# Chinbrook                                54                       54     54
# Crofton Park                            100                      100    100
# Denmark Hill                            100                      100    100
# Deptford                                100                      100    100
# Dulwich                                 100                      100    100
# East Dulwich                             99                       99     99
# Elephant and Castle                     300                      300    300
# Forest Hill                             100                      100    100
# Gipsy Hill                              199                      199    199
# Grove Park                               54                       54     54
# Herne Hill                              100                      100    100
# Hither Green                            100                      100    100
# Honor Oak                               100                      100    100
# Ladywell                                200                      200    200
# Lambeth                                 100                      100    100
# Lee                                      54                       54     54
# Lewisham                                100                      100    100
# New Cross                               100                      100    100
# Newington                               200                      200    200
# Nunhead                                 100                      100    100
# Oval                                    100                      100    100
# Peckham                                 100                      100    100
# Rotherhithe                             100                      100    100
# Selhurst                                 52                       52     52
# South Norwood                            52                       52     52
# Southend                                 72                       72     72
# St Johns                                100                      100    100
# Surrey Quays                            100                      100    100
# Tulse Hill                              200                      200    200
# Upper Norwood                            99                       99     99
# Walworth                                100                      100    100
# West Norwood                            100                      100    100
#
#                      Venue Latitude  Venue Longitude  Venue Category
# Neighbourhood
# Bankside                        100              100             100
# Bellingham                       72               72              72
# Bermondsey                      100              100             100
# Blackheath                       94               94              94
# Brixton                         100              100             100
# Brockley                        100              100             100
# Camberwell                      100              100             100
# Catford                          72               72              72
# Chinbrook                        54               54              54
# Crofton Park                    100              100             100
# Denmark Hill                    100              100             100
# Deptford                        100              100             100
# Dulwich                         100              100             100
# East Dulwich                     99               99              99
# Elephant and Castle             300              300             300
# Forest Hill                     100              100             100
# Gipsy Hill                      199              199             199
# Grove Park                       54               54              54
# Herne Hill                      100              100             100
# Hither Green                    100              100             100
# Honor Oak                       100              100             100
# Ladywell                        200              200             200
# Lambeth                         100              100             100
# Lee                              54               54              54
# Lewisham                        100              100             100
# New Cross                       100              100             100
# Newington                       200              200             200
# Nunhead                         100              100             100
# Oval                            100              100             100
# Peckham                         100              100             100
# Rotherhithe                     100              100             100
# Selhurst                         52               52              52
# South Norwood                    52               52              52
# Southend                         72               72              72
# St Johns                        100              100             100
# Surrey Quays                    100              100             100
# Tulse Hill                      200              200             200
# Upper Norwood                    99               99              99
# Walworth                        100              100             100
# West Norwood                    100              100             100

# %% [markdown]
# Check for  unique categories for the venues

# %%
print('There are {} uniques categories.'.format(len(se_venues['Venue Category'].unique())))
# Out:
# There are 194 uniques categories.

# %%
se_venue_unique_count = se_venues['Venue Category'].value_counts().to_frame(name='Count')

# %%
se_venue_unique_count.head()
# Out:
#                Count
# Pub              427
# Café             304
# Coffee Shop      301
# Park             219
# Grocery Store    161

# %%
se_venue_unique_count.describe()
# Out:
#             Count
# count  194.000000
# mean    22.025773
# std     49.566769
# min      1.000000
# 25%      4.000000
# 50%      7.000000
# 75%     18.000000
# max    427.000000

# %% [markdown]
# 3.2 Clustering
#
# For this section, the neighbourhoods in South East London will be clustered based on the processed data obtained above.
# 3.2.1 Libraries
#
# To get started, all the necessary libraries have been called in the libraries section above.
# 3.2.2 Map Visualization
#
# Using the geopy library, the latitude and longitude values of London is obtained.

# %%
address = 'London, United Kingdom'

geolocator = Nominatim(user_agent="ln_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of London are {}, {}.'.format(latitude, longitude))
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# c:\users\sudarshanrajan\appdata\local\programs\python\python37\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# c:\users\sudarshanrajan\appdata\local\programs\python\python37\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# c:\users\sudarshanrajan\appdata\local\programs\python\python37\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# c:\users\sudarshanrajan\appdata\local\programs\python\python37\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# c:\users\sudarshanrajan\appdata\local\programs\python\python37\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# c:\users\sudarshanrajan\appdata\local\programs\python\python37\lib\http\client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# c:\users\sudarshanrajan\appdata\local\programs\python\python37\lib\http\client.py in connect(self)
#    1391             self.sock = self._context.wrap_socket(self.sock,
# -> 1392                                                   server_hostname=server_hostname)
#    1393
#
# c:\users\sudarshanrajan\appdata\local\programs\python\python37\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     411             context=self,
# --> 412             session=session
#     413         )
#
# c:\users\sudarshanrajan\appdata\local\programs\python\python37\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     852                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 853                     self.do_handshake()
#     854             except (OSError, ValueError):
#
# c:\users\sudarshanrajan\appdata\local\programs\python\python37\lib\ssl.py in do_handshake(self, block)
#    1116                 self.settimeout(None)
# -> 1117             self._sslobj.do_handshake()
#    1118         finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1056)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# c:\users\sudarshanrajan\appdata\local\programs\python\python37\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# c:\users\sudarshanrajan\appdata\local\programs\python\python37\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# c:\users\sudarshanrajan\appdata\local\programs\python\python37\lib\urllib\request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# c:\users\sudarshanrajan\appdata\local\programs\python\python37\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# c:\users\sudarshanrajan\appdata\local\programs\python\python37\lib\urllib\request.py in https_open(self, req)
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#
# c:\users\sudarshanrajan\appdata\local\programs\python\python37\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#
# URLError: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1056)>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderServiceError                      Traceback (most recent call last)
# <ipython-input-75-265f646315f0> in <module>
#       2
#       3 geolocator = Nominatim(user_agent="ln_explorer")
# ----> 4 location = geolocator.geocode(address)
#       5 latitude = location.latitude
#       6 longitude = location.longitude
#
# c:\users\sudarshanrajan\appdata\local\programs\python\python37\lib\site-packages\geopy\geocoders\osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     385
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#     389
#
# c:\users\sudarshanrajan\appdata\local\programs\python\python37\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     384                 if "timed out" in message:
#     385                     raise GeocoderTimedOut('Service timed out')
# --> 386             raise GeocoderServiceError(message)
#     387
#     388         if hasattr(page, 'getcode'):
#
# GeocoderServiceError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1056)

# %%
# df_london_coordinates
map_london = folium.Map(location = [latitude, longitude], zoom_start = 12)
map_london
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-78e457e75a97> in <module>
#       1 # df_london_coordinates
# ----> 2 map_london = folium.Map(location = [latitude, longitude], zoom_start = 12)
#       3 map_london
#
# NameError: name 'latitude' is not defined

# %% [markdown]
# The South East London neighbourhoods are then superimposed on top as shown below, still using the foliumlibrary. Please note due to the location of the South East Loondon, you might need to zoom to see the superimposed areas.

# %%
# Adding markers to map
for lat, lng, borough, loc in zip(se_df['Latitude'], 
                                  se_df['Longitude'],
                                  se_df['Borough'],
                                  se_df['Location']):
    label = '{} - {}'.format(loc, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_london)  
    
display(map_london)

# %%
type(se_df)

# %% [markdown]
# 3.2.3 Analysing Each Neighborhood
#
# In this section, the objective is to check and explore the venues in each neighbourhood.

# %%
# one hot encoding
se_onehot = pd.get_dummies(se_venues[['Venue Category']], prefix = "", prefix_sep = "")

# %%
# add neighborhood column back to dataframe
se_onehot['Neighbourhood'] = se_venues['Neighbourhood']

# %%
# move neighborhood column to the first column
fixed_columns = [se_onehot.columns[-1]] + list(se_onehot.columns[:-1])
se_onehot = se_onehot[fixed_columns]

# %%
se_onehot.head(5) #the new one hot encoded dataframe

# %%
se_onehot.loc[se_onehot['African Restaurant'] != 0]

# %%
se_onehot.loc[se_onehot['Neighbourhood'] == 'Lewisham']

# %%
se_onehot.shape

# %% [markdown]
# Regrouping and Category Statistics¶

# %%
se_grouped = se_onehot.groupby('Neighbourhood').mean().reset_index()
se_grouped.head()

# %%
print("Before One-hot encoding:", se_df.shape)
print("After One-hot encoding:", se_grouped.shape)

# %%
se_grouped.to_csv('london_grouped.csv', index = False)

# %%
#Grouping of each Neighbourhoods with 10 common venues:

num_top_venues = 10 # Top common venues needed

for hood in se_grouped['Neighbourhood']:
    print("----"+hood+"----")
    temp = se_grouped[se_grouped['Neighbourhood'] == hood].T.reset_index()
    temp.columns = ['venue', 'freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending = False).reset_index(drop = True).head(num_top_venues))
    print('\n')

# %% [markdown]
# Creating new dataframe:
# Putting the common venues into pandas dataframe, the following return_most_common_venuesis used to sort the venues in descending order.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending = False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Then we create a new panda dataframe with 10 most common venues as shown below:

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighbourhoods_venues_sorted = pd.DataFrame(columns=columns)
neighbourhoods_venues_sorted['Neighbourhood'] = se_grouped['Neighbourhood']

for ind in np.arange(se_grouped.shape[0]):
    neighbourhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(se_grouped.iloc[ind, :], num_top_venues)

# %%
neighbourhoods_venues_sorted.head()

# %%
se_grouped_clustering = se_grouped.drop('Neighbourhood', 1)

# %% [markdown]
# 3.2.4 Clustering of Neighbourhoods
#
# The next thing to do now, is to create clusters of the neighbourhood using the k-means to cluster the neighbourhood into 5 clusters.

# %%
# set number of clusters
kclusters = 5

# run k-means clustering
kmeans = KMeans(n_clusters = kclusters, random_state=0).fit(se_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]

# %%
kmeans.labels_[0:10]

# %% [markdown]
# Now creating a new dataframe that includes the clusters as well as the top 10 venues for each neighbourhoods.

# %%
# add clustering labels
neighbourhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
se_merged = se_df

# %%
se_merged.head(3)

# %%
# match/merge SE London data with latitude/longitude for each neighborhood
se_merged_latlong = se_merged.join(neighbourhoods_venues_sorted.set_index('Neighbourhood'), on = 'Location')

# %%
se_merged_latlong.head(5)

# %%
se_clusters = se_merged_latlong

# %% [markdown]
# Please note, that the number of clusters was chosen as 5 for initial run.
# 3.2.5 Optimal Number of Clusters for K-mean
#
# To get the optimal number of clusters to be used for the K-mean, there are a number ways possible for the evaluation. Therefore, in this task, the following are used:

# %% [markdown]
# 1. Elbow Method
#
# The elbow method is used to solve the problem of selecting k. Interestingly, the elbow method is not perfect either but it gives significant insight that is perhaps not top optimal but sub-optimal to choosing the optimal number of clusters by fitting the model with a range of values for k.

# %%
# %matplotlib inline
import matplotlib
import numpy as np

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# SSE is initialize with empty values
# n_clusters is the "k" 
sse = {}
for n_cluster1 in range(2, 10):
    kmeans1 = KMeans(n_clusters = n_cluster1, max_iter = 500).fit(se_grouped_clustering)
    se_grouped_clustering["clusters"] = kmeans1.labels_
    
    # The inertia is the sum of distances of samples to their closest cluster centre
    sse[n_cluster1] = kmeans1.inertia_ 
plt.figure()
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of Clusters, k")
plt.ylabel("Sum of Squared Error, SSE")
# vertical line
plt.vlines(3, ymin = -2, ymax = 45, colors = 'red')
plt.show()

# %% [markdown]
# 2. Silhouette Coefficient

# %% [markdown]
# To find the optimal value of the number of clusters, k, the number of clusters is iterated corresponding Silhouette Coefficientis calculated for each of the k-values used. The highest Silhouette Coefficient gives the best match to its own cluster. Please see below:

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

for n_cluster2 in range(2, 10):
    kmeans2 = KMeans(n_clusters = n_cluster2, random_state = 0).fit(se_grouped_clustering)
    label2 = kmeans2.labels_
    sil_coeff = silhouette_score(se_grouped_clustering, label2, metric = 'euclidean')
    print("Where n_clusters = {}, the Silhouette Coefficient is {}".format(n_cluster2, sil_coeff))

# %% [markdown]
# From the result, the high the n_clusters the better the silhouette coefficient. For this project, a cluster value of 5 will be used.

# %%
se_clusters.columns

# %% [markdown]
# 3.2.6 Visualizing the Resulting Clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(se_clusters['Latitude'], se_clusters['Longitude'], se_clusters['Location'], se_clusters['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=20,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)

display(map_clusters)

# %% [markdown]
# Cluster 1

# %%
se_clusters.loc[se_clusters['Cluster Labels'] == 0, se_clusters.columns[[1] + list(range(5, se_clusters.shape[1]))]]

# %% [markdown]
# Clusters 2

# %%
se_clusters.loc[se_clusters['Cluster Labels'] == 1, se_clusters.columns[[1] + list(range(5, se_clusters.shape[1]))]]

# %% [markdown]
# Cluster 3

# %%
se_clusters.loc[se_clusters['Cluster Labels'] == 2, se_clusters.columns[[1] + list(range(5, se_clusters.shape[1]))]]

# %% [markdown]
# Cluster 4

# %%
se_clusters.loc[se_clusters['Cluster Labels'] == 3, se_clusters.columns[[1] + list(range(5, se_clusters.shape[1]))]]

# %% [markdown]
# Cluster 5

# %%
se_clusters.loc[se_clusters['Cluster Labels'] == 4, se_clusters.columns[[1] + list(range(5, se_clusters.shape[1]))]]

# %% [markdown]
# <h2>4. Result</h2>

# %% [markdown]
# The following are the highlights of the 5 clusters above:
#
#     a)Pubs, Cafe, Coffee Shops are popular in the South East London.
#     b)As for restaurants, the Italian Restaurants are very popular in the South East London area. Especially in
#       Southwark and Lambeth areas.
#     c)With the Lewisham area being the most condensed area of Africans in the South East Area, but no restaurants.
#     d)Although, the Clusters have variations, a very visible presence is the predominance of pubs.

# %% [markdown]
# <h2>5. Conclusion</h2>

# %% [markdown]
#  Clusters 2 and 3 are the most viable clusters to create a brand African Restaurant. They can flourish as there are no Top restaurants there for competetion.
